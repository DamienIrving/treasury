# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
infile = '/g/data/xv83/dbi599/treasury/FFDI/ACCESS-ESM1-5/ssp370/FFDIx_yr_ACCESS-ESM1-5_ssp370_r1i1p1f1_aus-states_1850-2100.csv'

# %%
df = pd.read_csv(infile)

# %%
df
# Out:
#      year          model       run  experiment    NSW    VIC    QLD     SA  \
# 0    1950  ACCESS-ESM1-5  r1i1p1f1  historical  33.77  22.46  32.00  35.80
# 1    1951  ACCESS-ESM1-5  r1i1p1f1  historical  38.49  30.01  34.18  34.79
# 2    1952  ACCESS-ESM1-5  r1i1p1f1  historical  48.22  41.62  38.32  54.88
# 3    1953  ACCESS-ESM1-5  r1i1p1f1  historical  49.50  47.51  30.54  50.23
# 4    1954  ACCESS-ESM1-5  r1i1p1f1  historical  57.13  52.61  40.63  46.41
# ..    ...            ...       ...         ...    ...    ...    ...    ...
# 146  2096  ACCESS-ESM1-5  r1i1p1f1      ssp370  66.07  42.71  44.85  59.30
# 147  2097  ACCESS-ESM1-5  r1i1p1f1      ssp370  68.58  57.63  51.99  70.08
# 148  2098  ACCESS-ESM1-5  r1i1p1f1      ssp370  63.35  56.46  42.23  82.65
# 149  2099  ACCESS-ESM1-5  r1i1p1f1      ssp370  61.62  55.08  42.84  59.82
# 150  2100  ACCESS-ESM1-5  r1i1p1f1      ssp370  62.92  56.78  42.73  69.71
#
#         WA    TAS     NT    AUS
# 0    42.76   8.59  38.27  33.35
# ...

# %%
fig, ax = plt.subplots(figsize=[15,7])
sns.scatterplot(
    ax=ax,
    data=df,
    x='year',
    y='NSW',
    hue='run'
)
ax.grid()
plt.show()
