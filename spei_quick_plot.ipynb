# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
infiles = {
    'ACCESS-CM2': '/g/data/xv83/dbi599/treasury/SPEI/ACCESS-CM2/ssp370/spei_mon_ACCESS-CM2_ssp370_r1i1p1f1_aus-states_1850-2100.csv',
    'MPI-ESM1-2-LR' : '/g/data/xv83/dbi599/treasury/SPEI/MPI-ESM1-2-LR/ssp370/spei_mon_MPI-ESM1-2-LR_ssp370_r1i1p1f1_aus-states_1850-2100.csv',
}

# %%
df_dict = {}
df_dict['ACCESS-CM2'] = pd.read_csv(infiles['ACCESS-CM2'])
df_dict['MPI-ESM1-2-LR'] = pd.read_csv(infiles['MPI-ESM1-2-LR'])

# %%
df_dict['ACCESS-CM2']
# Out:
#       year  month       model       run  experiment   NSW   VIC   QLD    SA  \
# 0     1850      1  ACCESS-CM2  r1i1p1f1  historical   NaN   NaN   NaN   NaN
# 1     1850      2  ACCESS-CM2  r1i1p1f1  historical   NaN   NaN   NaN   NaN
# 2     1850      3  ACCESS-CM2  r1i1p1f1  historical   NaN   NaN   NaN   NaN
# 3     1850      4  ACCESS-CM2  r1i1p1f1  historical   NaN   NaN   NaN   NaN
# 4     1850      5  ACCESS-CM2  r1i1p1f1  historical   NaN   NaN   NaN   NaN
# ...    ...    ...         ...       ...         ...   ...   ...   ...   ...
# 3007  2100      8  ACCESS-CM2  r1i1p1f1      ssp370 -0.97 -1.32 -0.50 -2.21
# 3008  2100      9  ACCESS-CM2  r1i1p1f1      ssp370 -0.97 -1.32 -0.63 -2.55
# 3009  2100     10  ACCESS-CM2  r1i1p1f1      ssp370 -1.44 -1.55 -0.90 -3.50
# 3010  2100     11  ACCESS-CM2  r1i1p1f1      ssp370 -2.08 -1.87 -1.05 -4.27
# 3011  2100     12  ACCESS-CM2  r1i1p1f1      ssp370 -4.31 -2.46 -1.50 -4.82
#
#         WA   TAS    NT   AUS
# 0      NaN   NaN   NaN   NaN
# 1      NaN   NaN   NaN   NaN
# 2      NaN   NaN   NaN   NaN
# 3      NaN   NaN   NaN   NaN
# 4      NaN   NaN   NaN   NaN
# ...    ...   ...   ...   ...
# 3007 -4.19 -1.78 -0.56 -2.03
# 3008 -4.04 -1.61 -0.82 -2.10
# 3009 -4.21 -1.45 -1.11 -2.44
# 3010 -4.85 -1.70 -1.29 -2.89
# 3011 -4.78 -1.59 -1.68 -3.36
#
# [3012 rows x 13 columns]

# %%
fig, ax = plt.subplots(figsize=[15,7])
df = df_dict['ACCESS-CM2']
sns.scatterplot(
    ax=ax,
    data=df[df['year'] >= 1950],
    x='year',
    y='AUS',
    hue='month',
)
ax.set_ylabel('SPEI')
ax.set_title('ACCESS-CM2 - AUS')
ax.grid()
plt.show()

# %%
def plot_location(model, location, start_year=1950, annual_mean=True):
    """Scatterplot for a given location"""

    df = df_dict[model]
    df = df[df['year'] >= start_year]
    if annual_mean:
        df = df.drop(['month', 'model', 'experiment'], axis=1).groupby(['year', 'run']).mean()
    fig, ax = plt.subplots(figsize=[15,7])
    sns.scatterplot(
        ax=ax,
        data=df,
        x='year',
        y=location,
        hue='run',
    )
    ax.set_ylabel('SPEI')
    ax.set_title(f'{model} - {location}')
    ax.grid()
    plt.show()

# %%
plot_location('ACCESS-CM2', 'AUS')

# %%
plot_location('MPI-ESM1-2-LR', 'AUS')

# %%
plot_location('ACCESS-CM2', 'VIC')

# %%
plot_location('MPI-ESM1-2-LR', 'VIC')
